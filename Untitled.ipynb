# %% [markdown]
# ## Importing important libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Loading the dataset

# %%
#Loading the data
df= pd.read_csv(r'AviationData.csv', encoding='latin1', index_col=0)

#Checking the first five rows of the dataset
df.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28560\4273609430.py:2: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv(r'AviationData.csv', encoding='latin1', index_col=0)
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
#
#                        Location        Country   Latitude  Longitude  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States        NaN        NaN
# 20001218X45447   BRIDGEPORT, CA  United States        NaN        NaN
# 20061025X01555    Saltville, VA  United States  36.922223 -81.878056
# 20001218X45448       EUREKA, CA  United States        NaN        NaN
# 20041105X01764       Canton, OH  United States        NaN        NaN
#
#                Airport.Code Airport.Name Injury.Severity  ...  \
# Event.Id                                                  ...
# 20001218X45444          NaN          NaN        Fatal(2)  ...
# 20001218X45447          NaN          NaN        Fatal(4)  ...
# 20061025X01555          NaN          NaN        Fatal(3)  ...
# 20001218X45448          NaN          NaN        Fatal(2)  ...
# 20041105X01764          NaN          NaN        Fatal(1)  ...
#
#                Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444          Personal         NaN                  2.0
# 20001218X45447          Personal         NaN                  4.0
# 20061025X01555          Personal         NaN                  3.0
# 20001218X45448          Personal         NaN                  2.0
# 20041105X01764          Personal         NaN                  1.0
#
#                Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                    0.0                  0.0             0.0
# 20001218X45447                    0.0                  0.0             0.0
# 20061025X01555                    NaN                  NaN             NaN
# 20001218X45448                    0.0                  0.0             0.0
# 20041105X01764                    2.0                  NaN             0.0
#
#                 Weather.Condition Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                Cruise  Probable Cause
# 20001218X45447                UNK               Unknown  Probable Cause
# 20061025X01555                IMC                Cruise  Probable Cause
# 20001218X45448                IMC                Cruise  Probable Cause
# 20041105X01764                VMC              Approach  Probable Cause
#
#                Publication.Date
# Event.Id
# 20001218X45444              NaN
# 20001218X45447       19-09-1996
# 20061025X01555       26-02-2007
# 20001218X45448       12-09-2000
# 20041105X01764       16-04-1980
#
# [5 rows x 30 columns]

# %%
#Checking the last five rows of the dataset
df.tail()
# Out:
#                Investigation.Type Accident.Number  Event.Date       Location  \
# Event.Id
# 20221227106491           Accident      ERA23LA093  2022-12-26  Annapolis, MD
# 20221227106494           Accident      ERA23LA095  2022-12-26    Hampton, NH
# 20221227106497           Accident      WPR23LA075  2022-12-26     Payson, AZ
# 20221227106498           Accident      WPR23LA076  2022-12-26     Morgan, UT
# 20221230106513           Accident      ERA23LA097  2022-12-29     Athens, GA
#
#                       Country Latitude Longitude Airport.Code Airport.Name  \
# Event.Id
# 20221227106491  United States      NaN       NaN          NaN          NaN
# 20221227106494  United States      NaN       NaN          NaN          NaN
# 20221227106497  United States  341525N  1112021W          PAN       PAYSON
# 20221227106498  United States      NaN       NaN          NaN          NaN
# 20221230106513  United States      NaN       NaN          NaN          NaN
#
#                Injury.Severity  ... Purpose.of.flight         Air.carrier  \
# Event.Id                        ...
# 20221227106491           Minor  ...          Personal                 NaN
# 20221227106494             NaN  ...               NaN                 NaN
# 20221227106497       Non-Fatal  ...          Personal                 NaN
# 20221227106498             NaN  ...          Personal  MC CESSNA 210N LLC
# 20221230106513           Minor  ...          Personal                 NaN
#
#                Total.Fatal.Injuries Total.Serious.Injuries  \
# Event.Id
# 20221227106491                  0.0                    1.0
# 20221227106494                  0.0                    0.0
# 20221227106497                  0.0                    0.0
# 20221227106498                  0.0                    0.0
# 20221230106513                  0.0                    1.0
#
#                Total.Minor.Injuries Total.Uninjured  Weather.Condition  \
# Event.Id
# 20221227106491                  0.0             0.0                NaN
# 20221227106494                  0.0             0.0                NaN
# 20221227106497                  0.0             1.0                VMC
# 20221227106498                  0.0             0.0                NaN
# 20221230106513                  0.0             1.0                NaN
#
#                Broad.phase.of.flight Report.Status Publication.Date
# Event.Id
# 20221227106491                   NaN           NaN       29-12-2022
# 20221227106494                   NaN           NaN              NaN
# 20221227106497                   NaN           NaN       27-12-2022
# 20221227106498                   NaN           NaN              NaN
# 20221230106513                   NaN           NaN       30-12-2022
#
# [5 rows x 30 columns]

# %%
#Checking the dataset shape
df.shape
# Out:
# (88889, 30)

# %%
#Checking the dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88889 entries, 20001218X45444 to 20221230106513
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Investigation.Type      88889 non-null  object
#  1   Accident.Number         88889 non-null  object
#  2   Event.Date              88889 non-null  object
#  3   Location                88837 non-null  object
#  4   Country                 88663 non-null  object
#  5   Latitude                34382 non-null  object
#  6   Longitude               34373 non-null  object
#  7   Airport.Code            50132 non-null  object
#  8   Airport.Name            52704 non-null  object
#  9   Injury.Severity         87889 non-null  object
#  10  Aircraft.damage         85695 non-null  object
#  11  Aircraft.Category       32287 non-null  object
#  12  Registration.Number     87507 non-null  object
#  13  Make                    88826 non-null  object
#  14  Model                   88797 non-null  object
#  15  Amateur.Built           88787 non-null  object
#  16  Number.of.Engines       82805 non-null  float64
#  17  Engine.Type             81793 non-null  object
#  18  FAR.Description         32023 non-null  object
#  19  Schedule                12582 non-null  object
#  20  Purpose.of.flight       82697 non-null  object
#  21  Air.carrier             16648 non-null  object
#  22  Total.Fatal.Injuries    77488 non-null  float64
#  23  Total.Serious.Injuries  76379 non-null  float64
#  24  Total.Minor.Injuries    76956 non-null  float64
#  25  Total.Uninjured         82977 non-null  float64
#  26  Weather.Condition       84397 non-null  object
#  27  Broad.phase.of.flight   61724 non-null  object
#  28  Report.Status           82505 non-null  object
#  29  Publication.Date        75118 non-null  object
# dtypes: float64(5), object(25)
# memory usage: 21.0+ MB

# %%
#Check a simplified version of the dataset information
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88889 entries, 20001218X45444 to 20221230106513
# Columns: 30 entries, Investigation.Type to Publication.Date
# dtypes: float64(5), object(25)
# memory usage: 21.0+ MB

# %%
#Check the summary statistics of the numerical columns
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# 75%                0.000000         2.000000
# max              380.000000       699.000000

# %%
#Describe the categorical columns
df.describe(include="O")
# Out:
#        Investigation.Type Accident.Number  Event.Date       Location  \
# count               88889           88889       88889          88837
# unique                  2           88863       14782          27758
# top              Accident      CEN22LA149  1984-06-30  ANCHORAGE, AK
# freq                85015               2          25            434
#
#               Country Latitude Longitude Airport.Code Airport.Name  \
# count           88663    34382     34373        50132        52704
# unique            219    25592     27156        10374        24870
# top     United States  332739N  0112457W         NONE      Private
# freq            82248       19        24         1488          240
#
#        Injury.Severity  ... Amateur.Built    Engine.Type FAR.Description  \
# count            87889  ...         88787          81793           32023
# unique             109  ...             2             12              31
# top          Non-Fatal  ...            No  Reciprocating             091
# freq             67357  ...         80312          69530           18221
#
#        Schedule Purpose.of.flight Air.carrier Weather.Condition  \
# count     12582             82697       16648             84397
# unique        3                26       13590                 4
# top        NSCH          Personal       Pilot               VMC
# freq       4474             49448         258             77303
#
#        Broad.phase.of.flight   Report.Status Publication.Date
# count                  61724           82505            75118
# unique                    12           17074             2924
# top                  Landing  Probable Cause       25-09-2020
# freq                   15428           61754            17019
#
# [4 rows x 25 columns]

# %%
#Checking for null values
df.isna().sum()
# Out:
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Latitude                  54507
# Longitude                 54516
# Airport.Code              38757
# Airport.Name              36185
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1382
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7096
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# Report.Status              6384
# Publication.Date          13771
# dtype: int64

# %%
#Checking for unique values in each column
for col in df:
    col_val=df[col].unique()
    print(f"{col}: '\n', {col_val}", '\n')
# Out:
# Investigation.Type: '
# ', ['Accident' 'Incident']
#
# Accident.Number: '
# ', ['SEA87LA080' 'LAX94LA336' 'NYC07LA005' ... 'WPR23LA075' 'WPR23LA076'
#  'ERA23LA097']
#
# Event.Date: '
# ', ['1948-10-24' '1962-07-19' '1974-08-30' ... '2022-12-22' '2022-12-26'
#  '2022-12-29']
#
# Location: '
# ', ['MOOSE CREEK, ID' 'BRIDGEPORT, CA' 'Saltville, VA' ... 'San Manual, AZ'
#  'Auburn Hills, MI' 'Brasnorte, ']
#
# Country: '
# ', ['United States' nan 'GULF OF MEXICO' 'Puerto Rico' 'ATLANTIC OCEAN'
#  'HIGH ISLAND' 'Bahamas' 'MISSING' 'Pakistan' 'Angola' 'Germany'
#  'Korea, Republic Of' 'Martinique' 'American Samoa' 'PACIFIC OCEAN'
#  'Canada' 'Bolivia' 'Mexico' 'Dominica' 'Netherlands Antilles' 'Iceland'
#  'Greece' 'Guam' 'Australia' 'CARIBBEAN SEA' 'West Indies' 'Japan'
#  'Philippines' 'Venezuela' 'Bermuda' 'San Juan Islands' 'Colombia'
#  'El Salvador' 'United Kingdom' 'British Virgin Islands' 'Netherlands'
#  'Costa Rica' 'Mozambique' 'Jamaica' 'Panama' 'Guyana' 'Norway'
#  'Hong Kong' 'Portugal' 'Malaysia' 'Turks And Caicos Islands'
#  'Northern Mariana Islands' 'Dominican Republic' 'Suriname' 'Honduras'
#  'Congo' 'Belize' 'Guatemala' 'Anguilla' 'France'
#  'St Vincent And The Grenadines' 'Haiti' 'Montserrat' 'Papua New Guinea'
#  'Cayman Islands' 'Sweden' 'Taiwan' 'Senegal' 'Barbados' 'BLOCK 651A'
#  'Brazil' 'Mauritius' 'Argentina' 'Kenya' 'Ecuador' 'Aruba' 'Saudi Arabia'
#  'Cuba' 'Italy' 'French Guiana' 'Denmark' 'Sudan' 'Spain'
#  'Federated States Of Micronesia' 'St Lucia' 'Switzerland'
#  'Central African Republic' 'Algeria' 'Turkey' 'Nicaragua'
#  'Marshall Islands' 'Trinidad And Tobago' 'Poland' 'Belarus' 'Austria'
#  'Malta' 'Cameroon' 'Solomon Islands' 'Zambia' 'Peru' 'Croatia' 'Fiji'
#  'South Africa' 'India' 'Ethiopia' 'Ireland' 'Chile' 'Antigua And Barbuda'
#  'Uganda' 'China' 'Cambodia' 'Paraguay' 'Thailand' 'Belgium' 'Gambia'
#  'Uruguay' 'Tanzania' 'Mali' 'Indonesia' 'Bahrain' 'Kazakhstan' 'Egypt'
#  'Russia' 'Cyprus' "Cote D'ivoire" 'Nigeria' 'Greenland' 'Vietnam'
#  'New Zealand' 'Singapore' 'Ghana' 'Gabon' 'Nepal' 'Slovakia' 'Finland'
#  'Liberia' 'Romania' 'Maldives' 'Antarctica' 'Zimbabwe' 'Botswana'
#  'Isle of Man' 'Latvia' 'Niger' 'French Polynesia' 'Guadeloupe'
#  'Ivory Coast' 'Tunisia' 'Eritrea' 'Gibraltar' 'Namibia' 'Czech Republic'
#  'Benin' 'Bosnia And Herzegovina' 'Israel' 'Estonia' 'St Kitts And Nevis'
#  'Sierra Leone' 'Corsica' 'Scotland' 'Reunion' 'United Arab Emirates'
#  'Afghanistan' 'Ukraine' 'Hungary' 'Bangladesh' 'Morocco' 'Iraq' 'Jordan'
#  'Qatar' 'Madagascar' 'Malawi' 'Unknown' 'Central Africa' 'South Sudan'
#  'Saint Barthelemy' 'Micronesia' 'South Korea' 'Kyrgyzstan'
#  'Turks And Caicos' 'Eswatini' 'Tokelau' 'Sint Maarten' 'Macao'
#  'Seychelles' 'Rwanda' 'Palau' 'Luxembourg' 'Lebanon'
#  'Bosnia and Herzegovina' 'Libya' 'Guinea'
#  'Saint Vincent and the Grenadines' 'UN' 'Iran' 'Lithuania' 'Malampa'
#  'Antigua and Barbuda' 'AY' 'Chad' 'Cayenne' 'New Caledonia' 'Yemen'
#  'Slovenia' 'Nauru' 'Niue' 'Bulgaria' 'Republic of North Macedonia'
#  'Virgin Islands' 'Somalia' 'Pacific Ocean' 'Obyan' 'Mauritania' 'Albania'
#  'Wolseley' 'Wallis and Futuna' 'Saint Pierre and Miquelon' 'Georgia'
#  "Côte d'Ivoire" 'South Korean' 'Serbia' 'MU' 'Guernsey' 'Great Britain'
#  'Turks and Caicos Islands']
#
# Latitude: '
# ', [nan 36.922223 42.445277 ... '321814N' '039101N' '373829N']
#
# Longitude: '
# ', [nan -81.878056 -70.758333 ... '1114536W' '0835218W' '0121410W']
#
# Airport.Code: '
# ', [nan 'N58' 'JAX' ... 'SKMD' 'OMAA' 'EIKH']
#
# Airport.Name: '
# ', [nan 'BLACKBURN AG STRIP' 'HANOVER' ... 'HAWKINSVILLE-PULASKI COUNTY'
#  'Lewiston Municipal Airport' 'WICHITA DWIGHT D EISENHOWER NT']
#
# Injury.Severity: '
# ', ['Fatal(2)' 'Fatal(4)' 'Fatal(3)' 'Fatal(1)' 'Non-Fatal' 'Incident'
#  'Fatal(8)' 'Fatal(78)' 'Fatal(7)' 'Fatal(6)' 'Fatal(5)' 'Fatal(153)'
#  'Fatal(12)' 'Fatal(14)' 'Fatal(23)' 'Fatal(10)' 'Fatal(11)' 'Fatal(9)'
#  'Fatal(17)' 'Fatal(13)' 'Fatal(29)' 'Fatal(70)' 'Unavailable'
#  'Fatal(135)' 'Fatal(31)' 'Fatal(256)' 'Fatal(25)' 'Fatal(82)'
#  'Fatal(156)' 'Fatal(28)' 'Fatal(18)' 'Fatal(43)' 'Fatal(15)' 'Fatal(270)'
#  'Fatal(144)' 'Fatal(174)' 'Fatal(111)' 'Fatal(131)' 'Fatal(20)'
#  'Fatal(73)' 'Fatal(27)' 'Fatal(34)' 'Fatal(87)' 'Fatal(30)' 'Fatal(16)'
#  'Fatal(47)' 'Fatal(56)' 'Fatal(37)' 'Fatal(132)' 'Fatal(68)' 'Fatal(54)'
#  'Fatal(52)' 'Fatal(65)' 'Fatal(72)' 'Fatal(160)' 'Fatal(189)'
#  'Fatal(123)' 'Fatal(33)' 'Fatal(110)' 'Fatal(230)' 'Fatal(97)'
#  'Fatal(349)' 'Fatal(125)' 'Fatal(35)' 'Fatal(228)' 'Fatal(75)'
#  'Fatal(104)' 'Fatal(229)' 'Fatal(80)' 'Fatal(217)' 'Fatal(169)'
#  'Fatal(88)' 'Fatal(19)' 'Fatal(60)' 'Fatal(113)' 'Fatal(143)' 'Fatal(83)'
#  'Fatal(24)' 'Fatal(44)' 'Fatal(64)' 'Fatal(92)' 'Fatal(118)' 'Fatal(265)'
#  'Fatal(26)' 'Fatal(138)' 'Fatal(206)' 'Fatal(71)' 'Fatal(21)' 'Fatal(46)'
#  'Fatal(102)' 'Fatal(115)' 'Fatal(141)' 'Fatal(55)' 'Fatal(121)'
#  'Fatal(45)' 'Fatal(145)' 'Fatal(117)' 'Fatal(107)' 'Fatal(124)'
#  'Fatal(49)' 'Fatal(154)' 'Fatal(96)' 'Fatal(114)' 'Fatal(199)'
#  'Fatal(89)' 'Fatal(57)' 'Fatal' nan 'Minor' 'Serious']
#
# Aircraft.damage: '
# ', ['Destroyed' 'Substantial' 'Minor' nan 'Unknown']
#
# Aircraft.Category: '
# ', [nan 'Airplane' 'Helicopter' 'Glider' 'Balloon' 'Gyrocraft' 'Ultralight'
#  'Unknown' 'Blimp' 'Powered-Lift' 'Weight-Shift' 'Powered Parachute'
#  'Rocket' 'WSFT' 'UNK' 'ULTR']
#
# Registration.Number: '
# ', ['NC6404' 'N5069P' 'N5142R' ... 'N749PJ' 'N210CU' 'N9026P']
#
# Make: '
# ', ['Stinson' 'Piper' 'Cessna' ... 'JAMES R DERNOVSEK' 'ORLICAN S R O'
#  'ROYSE RALPH L']
#
# Model: '
# ', ['108-3' 'PA24-180' '172M' ... 'ROTORWAY EXEC 162-F' 'KITFOX S5'
#  'M-8 EAGLE']
#
# Amateur.Built: '
# ', ['No' 'Yes' nan]
#
# Number.of.Engines: '
# ', [ 1. nan  2.  0.  3.  4.  8.  6.]
#
# Engine.Type: '
# ', ['Reciprocating' nan 'Turbo Fan' 'Turbo Shaft' 'Unknown' 'Turbo Prop'
#  'Turbo Jet' 'Electric' 'Hybrid Rocket' 'Geared Turbofan' 'LR' 'NONE'
#  'UNK']
#
# FAR.Description: '
# ', [nan 'Part 129: Foreign' 'Part 91: General Aviation'
#  'Part 135: Air Taxi & Commuter' 'Part 125: 20+ Pax,6000+ lbs'
#  'Part 121: Air Carrier' 'Part 137: Agricultural'
#  'Part 133: Rotorcraft Ext. Load' 'Unknown' 'Part 91F: Special Flt Ops.'
#  'Non-U.S., Non-Commercial' 'Public Aircraft' 'Non-U.S., Commercial'
#  'Public Use' 'Armed Forces' 'Part 91 Subpart K: Fractional' '091' 'NUSC'
#  '135' 'NUSN' '121' '137' '129' '133' '091K' 'UNK' 'PUBU' 'ARMF' '103'
#  '125' '437' '107']
#
# Schedule: '
# ', [nan 'SCHD' 'NSCH' 'UNK']
#
# Purpose.of.flight: '
# ', ['Personal' nan 'Business' 'Instructional' 'Unknown' 'Ferry'
#  'Executive/corporate' 'Aerial Observation' 'Aerial Application'
#  'Public Aircraft' 'Skydiving' 'Other Work Use' 'Positioning'
#  'Flight Test' 'Air Race/show' 'Air Drop' 'Public Aircraft - Federal'
#  'Glider Tow' 'Public Aircraft - Local' 'External Load'
#  'Public Aircraft - State' 'Banner Tow' 'Firefighting' 'Air Race show'
#  'PUBS' 'ASHO' 'PUBL']
#
# Air.carrier: '
# ', [nan 'Air Canada' 'Rocky Mountain Helicopters, In' ...
#  'SKY WEST AVIATION INC TRUSTEE' 'GERBER RICHARD E' 'MC CESSNA 210N LLC']
#
# Total.Fatal.Injuries: '
# ', [  2.   4.   3.   1.  nan   0.   8.  78.   7.   6.   5. 153.  12.  14.
#   23.  10.  11.   9.  17.  13.  29.  70. 135.  31. 256.  25.  82. 156.
#   28.  18.  43.  15. 270. 144. 174. 111. 131.  20.  73.  27.  34.  87.
#   30.  16.  47.  56.  37. 132.  68.  54.  52.  65.  72. 160. 189. 123.
#   33. 110. 230.  97. 349. 125.  35. 228.  75. 104. 229.  80. 217. 169.
#   88.  19.  60. 113. 143.  83.  24.  44.  64.  92. 118. 265.  26. 138.
#  206.  71.  21.  46. 102. 115. 141.  55. 121.  45. 145. 117. 107. 124.
#   49. 154.  96. 114. 199.  89.  57. 152.  90. 103. 158. 157.  42.  77.
#  127.  50. 239. 295.  58. 162. 150. 224.  62.  66. 112. 188.  41. 176.]
#
# Total.Serious.Injuries: '
# ', [  0.  nan   2.   1.   6.   4.   5.  10.   3.   8.   9.   7.  15.  17.
#   28.  26.  47.  14.  81.  13. 106.  60.  16.  21.  50.  44.  18.  12.
#   45.  39.  43.  11.  25.  59.  23.  55.  63.  88.  41.  34.  53.  33.
#   67.  35.  20. 137.  19.  27. 125. 161.  22.]
#
# Total.Minor.Injuries: '
# ', [  0.  nan   1.   3.   2.   4.  24.   6.   5.  25.  17.  19.  33.  14.
#    8.  13.  15.   7.   9.  16.  20.  11.  12.  10.  38.  42.  29.  62.
#   28.  31.  39.  32.  18.  27.  57.  50.  23. 125.  45.  26.  36.  69.
#   21.  96.  30.  22.  58. 171.  65.  71. 200.  68.  47. 380.  35.  43.
#   84.  40.]
#
# Total.Uninjured: '
# ', [  0.  nan  44.   2.   1.   3.   6.   4. 149.  12. 182. 154.   5.  10.
#    7. 119.  36.  51.  16.  83.   9.  68.  30.  20.  18.   8. 108.  11.
#  152.  21.  48.  56. 113. 129. 109.  29.  13.  84.  74. 142. 102. 393.
#  128. 112.  17.  65.  67. 136.  23. 116.  22.  57.  58.  73. 203.  31.
#  201. 412. 159.  39. 186. 588.  82.  95. 146. 190. 245. 172.  52.  25.
#   59. 131. 151. 180. 150.  86.  19. 133. 240.  15. 145. 125. 440.  77.
#  122. 205. 289. 110.  79.  66.  87.  78.  49. 104. 250.  33. 138. 100.
#   53. 158. 127. 160. 260.  47.  38. 165. 495.  81.  41.  14.  72.  98.
#  263. 188. 239.  27. 105. 111. 212. 157.  46. 121.  75.  71.  45.  91.
#   99.  85.  96.  50.  93. 276. 365. 371. 200. 103. 189.  37. 107.  61.
#   26. 271. 130.  89. 439. 132. 219.  43. 238. 195. 118. 175.  32. 507.
#  421.  90. 225. 269. 169. 236. 224. 134. 106. 331. 140.  94. 192. 161.
#  270.  69. 436. 213. 233. 115.  42. 167. 137. 114. 148. 222.  92. 375.
#   76. 171. 173. 246. 234. 123. 220. 202. 408. 279. 363. 135. 528. 334.
#  178. 147. 126.  62.  70.  97. 228. 226.  64. 290. 206. 297. 349. 208.
#  144.  54.  24. 258. 304. 274. 286.  55. 199. 221.  80. 272. 211. 262.
#  441. 194. 309. 185. 261. 241. 383. 177. 259. 244. 254. 156.  40.  34.
#  247. 176.  63.  28. 218. 282. 320. 204. 124. 215. 298. 120. 280. 179.
#  315. 461. 153.  60. 308.  88. 361. 277. 191. 235. 187. 101. 162.  35.
#  197. 193. 164. 370. 387. 163. 139. 267. 357. 339. 288. 231. 300. 255.
#  306. 443. 385. 248. 459. 141. 414. 229. 166. 209. 184. 168. 170. 198.
#  299. 573. 223. 265. 322. 196. 117. 253. 399. 360. 252. 217. 155. 183.
#  227. 249. 329. 340. 699. 325. 287. 143. 243. 230. 386. 181. 257. 283.
#  404. 319. 450. 356. 216. 174. 558. 214. 448. 324. 338. 273. 232. 401.
#  312. 368. 501. 237. 307. 296. 291. 403. 314. 285. 311. 293. 352. 332.
#  384. 275. 210. 268. 326. 454. 278. 576. 380. 394. 362. 397. 359. 264.
#  333. 367. 302. 348. 351. 358. 295. 321. 521. 301. 294. 378. 207. 406.
#  251. 455.]
#
# Weather.Condition: '
# ', ['UNK' 'IMC' 'VMC' nan 'Unk']
#
# Broad.phase.of.flight: '
# ', ['Cruise' 'Unknown' 'Approach' 'Climb' 'Takeoff' 'Landing' 'Taxi'
#  'Descent' 'Maneuvering' 'Standing' 'Go-around' 'Other' nan]
#
# Report.Status: '
# ', ['Probable Cause' 'Factual' 'Foreign' ...
#  'The pilot did not ensure adequate clearance from construction vehicles during taxi.'
#  'The pilot\x92s failure to secure the magneto switch before attempting to hand rotate the engine which resulted in an inadvertent engine start, a runaway airplane, and subsequent impact with parked airplanes. Contributing to the accident was the failure to properly secure the airplane with chocks.'
#  'The pilot\x92s loss of control due to a wind gust during landing.']
#
# Publication.Date: '
# ', [nan '19-09-1996' '26-02-2007' ... '22-12-2022' '23-12-2022' '29-12-2022']

# %% [markdown]
# ## Data Cleaning

# %%
#Making a copy of the original dataframe
df1 = df.copy(deep=True)
df1.head()
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
#
#                        Location        Country   Latitude  Longitude  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States        NaN        NaN
# 20001218X45447   BRIDGEPORT, CA  United States        NaN        NaN
# 20061025X01555    Saltville, VA  United States  36.922223 -81.878056
# 20001218X45448       EUREKA, CA  United States        NaN        NaN
# 20041105X01764       Canton, OH  United States        NaN        NaN
#
#                Airport.Code Airport.Name Injury.Severity  ...  \
# Event.Id                                                  ...
# 20001218X45444          NaN          NaN        Fatal(2)  ...
# 20001218X45447          NaN          NaN        Fatal(4)  ...
# 20061025X01555          NaN          NaN        Fatal(3)  ...
# 20001218X45448          NaN          NaN        Fatal(2)  ...
# 20041105X01764          NaN          NaN        Fatal(1)  ...
#
#                Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444          Personal         NaN                  2.0
# 20001218X45447          Personal         NaN                  4.0
# 20061025X01555          Personal         NaN                  3.0
# 20001218X45448          Personal         NaN                  2.0
# 20041105X01764          Personal         NaN                  1.0
#
#                Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                    0.0                  0.0             0.0
# 20001218X45447                    0.0                  0.0             0.0
# 20061025X01555                    NaN                  NaN             NaN
# 20001218X45448                    0.0                  0.0             0.0
# 20041105X01764                    2.0                  NaN             0.0
#
#                 Weather.Condition Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                Cruise  Probable Cause
# 20001218X45447                UNK               Unknown  Probable Cause
# 20061025X01555                IMC                Cruise  Probable Cause
# 20001218X45448                IMC                Cruise  Probable Cause
# 20041105X01764                VMC              Approach  Probable Cause
#
#                Publication.Date
# Event.Id
# 20001218X45444              NaN
# 20001218X45447       19-09-1996
# 20061025X01555       26-02-2007
# 20001218X45448       12-09-2000
# 20041105X01764       16-04-1980
#
# [5 rows x 30 columns]

# %%
#Checking the columns of the dataset
df1.columns
# Out:
# Index(['Investigation.Type', 'Accident.Number', 'Event.Date', 'Location',
#        'Country', 'Latitude', 'Longitude', 'Airport.Code', 'Airport.Name',
#        'Injury.Severity', 'Aircraft.damage', 'Aircraft.Category',
#        'Registration.Number', 'Make', 'Model', 'Amateur.Built',
#        'Number.of.Engines', 'Engine.Type', 'FAR.Description', 'Schedule',
#        'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
#Striping off spaces and changing all letters to lowercase 
df1.columns= df1.columns.str.lower().str.strip().str.replace(".", "_")
df1.columns
# Out:
# Index(['investigation_type', 'accident_number', 'event_date', 'location',
#        'country', 'latitude', 'longitude', 'airport_code', 'airport_name',
#        'injury_severity', 'aircraft_damage', 'aircraft_category',
#        'registration_number', 'make', 'model', 'amateur_built',
#        'number_of_engines', 'engine_type', 'far_description', 'schedule',
#        'purpose_of_flight', 'air_carrier', 'total_fatal_injuries',
#        'total_serious_injuries', 'total_minor_injuries', 'total_uninjured',
#        'weather_condition', 'broad_phase_of_flight', 'report_status',
#        'publication_date'],
#       dtype='object')

# %%
#Checking for duplicates
df1.duplicated().sum()
# Out:
# 0

# %%
#Checking for the value counts of the categorical columns
for col in df1.select_dtypes(include="O"):
    val_cnt= df1[col].value_counts(dropna=False)
    print(f"{val_cnt}", '\n' )
# Out:
# investigation_type
# Accident    85015
# Incident     3874
# Name: count, dtype: int64
#
# accident_number
# CEN22LA149    2
# WPR23LA041    2
# WPR23LA045    2
# DCA22WA214    2
# DCA22WA089    2
#              ..
# LAX92FA065    1
# ANC92T#A12    1
# MIA92LA049    1
# NYC92LA048    1
# ERA23LA097    1
# Name: count, Length: 88863, dtype: int64
#
# event_date
# 1984-06-30    25
# 1982-05-16    25
# 2000-07-08    25
# 1983-08-05    24
# 1984-08-25    24
#               ..
# 2014-03-16     1
# 2014-03-15     1
# 2014-03-12     1
# 2014-03-10     1
# 2022-12-29     1
# Name: count, Length: 14782, dtype: int64
#
# location
# ANCHORAGE, AK       434
# MIAMI, FL           200
# ALBUQUERQUE, NM     196
# HOUSTON, TX         193
# CHICAGO, IL         184
#                    ...
# MALLARDS LDG, GA      1
# LODGEPOLE, MT         1
# VERNILLION, SD        1
# MCMECHEN, WV          1
# Brasnorte,            1
# Name: count, Length: 27759, dtype: int64
#
# country
# United States                       82248
# Brazil                                374
# Canada                                359
# Mexico                                358
# United Kingdom                        344
#                                     ...
# Seychelles                              1
# Palau                                   1
# Libya                                   1
# Saint Vincent and the Grenadines        1
# Turks and Caicos Islands                1
# Name: count, Length: 220, dtype: int64
#
# latitude
# NaN          54507
# 332739N         19
# 335219N         18
# 32.815556       17
# 334118N         17
#              ...
# 345832N          1
# 31.991666        1
# 444947N          1
# 034358N          1
# 373829N          1
# Name: count, Length: 25593, dtype: int64
#
# longitude
# NaN            54516
# 0112457W          24
# 1114342W          18
# 1151140W          17
# -104.673056       17
#                ...
# 0824538W           1
# 0782055W           1
# 0823627W           1
# 0116352W           1
# 0121410W           1
# Name: count, Length: 27157, dtype: int64
#
# airport_code
# NaN     38757
# NONE     1488
# PVT       485
# APA       160
# ORD       149
#         ...
# RLO         1
# TN95        1
# IGI         1
# 3M8         1
# EIKH        1
# Name: count, Length: 10375, dtype: int64
#
# airport_name
# NaN                               36185
# Private                             240
# PRIVATE                             224
# Private Airstrip                    153
# NONE                                146
#                                   ...
# GEORGE CAMPERT MEMORIAL               1
# WESTCHESTER COUNTY ARPT               1
# IL VALLEY PARACHUTE CLUB              1
# LAUGHLIN/BULLHEAD                     1
# WICHITA DWIGHT D EISENHOWER NT        1
# Name: count, Length: 24871, dtype: int64
#
# injury_severity
# Non-Fatal     67357
# Fatal(1)       6167
# Fatal          5262
# Fatal(2)       3711
# Incident       2219
#               ...
# Fatal(80)         1
# Fatal(217)        1
# Fatal(169)        1
# Fatal(88)         1
# Fatal(189)        1
# Name: count, Length: 110, dtype: int64
#
# aircraft_damage
# Substantial    64148
# Destroyed      18623
# NaN             3194
# Minor           2805
# Unknown          119
# Name: count, dtype: int64
#
# aircraft_category
# NaN                  56602
# Airplane             27617
# Helicopter            3440
# Glider                 508
# Balloon                231
# Gyrocraft              173
# Weight-Shift           161
# Powered Parachute       91
# Ultralight              30
# Unknown                 14
# WSFT                     9
# Powered-Lift             5
# Blimp                    4
# UNK                      2
# Rocket                   1
# ULTR                     1
# Name: count, dtype: int64
#
# registration_number
# NaN       1382
# NONE       344
# UNREG      126
# UNK         13
# USAF         9
#           ...
# N93478       1
# N519UA       1
# N8840W       1
# N21040       1
# N9026P       1
# Name: count, Length: 79105, dtype: int64
#
# make
# Cessna             22227
# Piper              12029
# CESSNA              4922
# Beech               4330
# PIPER               2841
#                    ...
# Leonard Walters        1
# Maule Air Inc.         1
# Motley Vans            1
# Perlick                1
# ROYSE RALPH L          1
# Name: count, Length: 8238, dtype: int64
#
# model
# 152              2367
# 172              1756
# 172N             1164
# PA-28-140         932
# 150               829
#                  ...
# GC-1-A              1
# 737-3S3             1
# MBB-BK117-B2        1
# GLASSAIR GL25       1
# M-8 EAGLE           1
# Name: count, Length: 12319, dtype: int64
#
# amateur_built
# No     80312
# Yes     8475
# NaN      102
# Name: count, dtype: int64
#
# engine_type
# Reciprocating      69530
# NaN                 7096
# Turbo Shaft         3609
# Turbo Prop          3391
# Turbo Fan           2481
# Unknown             2051
# Turbo Jet            703
# Geared Turbofan       12
# Electric              10
# LR                     2
# NONE                   2
# Hybrid Rocket          1
# UNK                    1
# Name: count, dtype: int64
#
# far_description
# NaN                               56866
# 091                               18221
# Part 91: General Aviation          6486
# NUSN                               1584
# NUSC                               1013
# 137                                1010
# 135                                 746
# 121                                 679
# Part 137: Agricultural              437
# UNK                                 371
# Part 135: Air Taxi & Commuter       298
# PUBU                                253
# 129                                 246
# Part 121: Air Carrier               165
# 133                                 107
# Part 129: Foreign                   100
# Non-U.S., Non-Commercial             97
# Non-U.S., Commercial                 93
# Part 133: Rotorcraft Ext. Load       32
# Unknown                              22
# Public Use                           19
# 091K                                 14
# ARMF                                  8
# Part 125: 20+ Pax,6000+ lbs           5
# 125                                   5
# 107                                   4
# 103                                   2
# Public Aircraft                       2
# Part 91 Subpart K: Fractional         1
# Part 91F: Special Flt Ops.            1
# 437                                   1
# Armed Forces                          1
# Name: count, dtype: int64
#
# schedule
# NaN     76307
# NSCH     4474
# UNK      4099
# SCHD     4009
# Name: count, dtype: int64
#
# purpose_of_flight
# Personal                     49448
# Instructional                10601
# Unknown                       6802
# NaN                           6192
# Aerial Application            4712
# Business                      4018
# Positioning                   1646
# Other Work Use                1264
# Ferry                          812
# Aerial Observation             794
# Public Aircraft                720
# Executive/corporate            553
# Flight Test                    405
# Skydiving                      182
# External Load                  123
# Public Aircraft - Federal      105
# Banner Tow                     101
# Air Race show                   99
# Public Aircraft - Local         74
# Public Aircraft - State         64
# Air Race/show                   59
# Glider Tow                      53
# Firefighting                    40
# Air Drop                        11
# ASHO                             6
# PUBS                             4
# PUBL                             1
# Name: count, dtype: int64
#
# air_carrier
# NaN                                  72241
# Pilot                                  258
# American Airlines                       90
# United Airlines                         89
# Delta Air Lines                         53
#                                      ...
# American Classic Outfitters, Inc.        1
# Great Lakes Aviation, Ltd.               1
# Harold Parker                            1
# Ernie Dale Willis                        1
# MC CESSNA 210N LLC                       1
# Name: count, Length: 13591, dtype: int64
#
# weather_condition
# VMC    77303
# IMC     5976
# NaN     4492
# UNK      856
# Unk      262
# Name: count, dtype: int64
#
# broad_phase_of_flight
# NaN            27165
# Landing        15428
# Takeoff        12493
# Cruise         10269
# Maneuvering     8144
# Approach        6546
# Climb           2034
# Taxi            1958
# Descent         1887
# Go-around       1353
# Standing         945
# Unknown          548
# Other            119
# Name: count, dtype: int64
#
# report_status
# Probable Cause                                                                                                                                                       61754
# NaN                                                                                                                                                                   6384
# Foreign                                                                                                                                                               1999
# <br /><br />                                                                                                                                                           167
# Factual                                                                                                                                                                145
#                                                                                                                                                                      ...
# The pilot's incapacitation due to a ruptured berry aneurysm during takeoff.                                                                                              1
# The unauthorized operation of the helicopter by a non-certificated and unqualified individual who failed to maintain helicopter control.                                 1
# A loss of engine power due to the pilot's failure to utilize carburetor heat while maneuvering.\r\n.                                                                     1
# The pilot's failure to maintain adequate separation behind a corporate jet, which resulted in an encounter with wake turbulence and a subsequent loss of control.        1
# The pilots loss of control due to a wind gust during landing.                                                                                                           1
# Name: count, Length: 17075, dtype: int64
#
# publication_date
# 25-09-2020    17019
# NaN           13771
# 26-09-2020     1769
# 03-11-2020     1155
# 31-03-1993      452
#               ...
# 31-12-2004        1
# 07-12-2000        1
# 16-12-2004        1
# 20-12-2004        1
# 29-12-2022        1
# Name: count, Length: 2925, dtype: int64

# %%
#Drop the unnecessary columns
df1.drop(columns=["investigation_type", "accident_number", "airport_code", "airport_name", "registration_number", 
                  "publication_date", "report_status", "air_carrier"], axis=1, inplace=True)
df1.columns
# Out:
# Index(['event_date', 'location', 'country', 'latitude', 'longitude',
#        'injury_severity', 'aircraft_damage', 'aircraft_category', 'make',
#        'model', 'amateur_built', 'number_of_engines', 'engine_type',
#        'far_description', 'schedule', 'purpose_of_flight',
#        'total_fatal_injuries', 'total_serious_injuries',
#        'total_minor_injuries', 'total_uninjured', 'weather_condition',
#        'broad_phase_of_flight'],
#       dtype='object')

# %%
#To check if the columns dropped
df1.shape
# Out:
# (88889, 22)

# %%
#Fill the null values in categorical columns with "Unknown"
def fill_nans_with_unknown(df1):
    """
    Fills all NaN values in categorical columns with the string "Unknown"
    """
    for col in df1.select_dtypes(include="O").columns:
        df1[col] = df1[col].fillna("Unknown")
    return df1

fill_nans_with_unknown(df1)
# Out:
#                 event_date         location        country   latitude  \
# Event.Id
# 20001218X45444  1948-10-24  MOOSE CREEK, ID  United States    Unknown
# 20001218X45447  1962-07-19   BRIDGEPORT, CA  United States    Unknown
# 20061025X01555  1974-08-30    Saltville, VA  United States  36.922223
# 20001218X45448  1977-06-19       EUREKA, CA  United States    Unknown
# 20041105X01764  1979-08-02       Canton, OH  United States    Unknown
# ...                    ...              ...            ...        ...
# 20221227106491  2022-12-26    Annapolis, MD  United States    Unknown
# 20221227106494  2022-12-26      Hampton, NH  United States    Unknown
# 20221227106497  2022-12-26       Payson, AZ  United States    341525N
# 20221227106498  2022-12-26       Morgan, UT  United States    Unknown
# 20221230106513  2022-12-29       Athens, GA  United States    Unknown
#
#                 longitude injury_severity aircraft_damage aircraft_category  \
# Event.Id
# 20001218X45444    Unknown        Fatal(2)       Destroyed           Unknown
# 20001218X45447    Unknown        Fatal(4)       Destroyed           Unknown
# 20061025X01555 -81.878056        Fatal(3)       Destroyed           Unknown
# 20001218X45448    Unknown        Fatal(2)       Destroyed           Unknown
# 20041105X01764    Unknown        Fatal(1)       Destroyed           Unknown
# ...                   ...             ...             ...               ...
# 20221227106491    Unknown           Minor         Unknown           Unknown
# 20221227106494    Unknown         Unknown         Unknown           Unknown
# 20221227106497   1112021W       Non-Fatal     Substantial          Airplane
# 20221227106498    Unknown         Unknown         Unknown           Unknown
# 20221230106513    Unknown           Minor         Unknown           Unknown
#
#                                       make      model  ...    engine_type  \
# Event.Id                                               ...
# 20001218X45444                     Stinson      108-3  ...  Reciprocating
# 20001218X45447                       Piper   PA24-180  ...  Reciprocating
# 20061025X01555                      Cessna       172M  ...  Reciprocating
# 20001218X45448                    Rockwell        112  ...  Reciprocating
# 20041105X01764                      Cessna        501  ...        Unknown
# ...                                    ...        ...  ...            ...
# 20221227106491                       PIPER  PA-28-151  ...        Unknown
# 20221227106494                    BELLANCA       7ECA  ...        Unknown
# 20221227106497  AMERICAN CHAMPION AIRCRAFT      8GCBC  ...        Unknown
# 20221227106498                      CESSNA       210N  ...        Unknown
# 20221230106513                       PIPER  PA-24-260  ...        Unknown
#
#                 far_description schedule purpose_of_flight  \
# Event.Id
# 20001218X45444          Unknown  Unknown          Personal
# 20001218X45447          Unknown  Unknown          Personal
# 20061025X01555          Unknown  Unknown          Personal
# 20001218X45448          Unknown  Unknown          Personal
# 20041105X01764          Unknown  Unknown          Personal
# ...                         ...      ...               ...
# 20221227106491              091  Unknown          Personal
# 20221227106494          Unknown  Unknown           Unknown
# 20221227106497              091  Unknown          Personal
# 20221227106498              091  Unknown          Personal
# 20221230106513              091  Unknown          Personal
#
#                total_fatal_injuries total_serious_injuries  \
# Event.Id
# 20001218X45444                  2.0                    0.0
# 20001218X45447                  4.0                    0.0
# 20061025X01555                  3.0                    NaN
# 20001218X45448                  2.0                    0.0
# 20041105X01764                  1.0                    2.0
# ...                             ...                    ...
# 20221227106491                  0.0                    1.0
# 20221227106494                  0.0                    0.0
# 20221227106497                  0.0                    0.0
# 20221227106498                  0.0                    0.0
# 20221230106513                  0.0                    1.0
#
#                 total_minor_injuries  total_uninjured  weather_condition  \
# Event.Id
# 20001218X45444                   0.0              0.0                UNK
# 20001218X45447                   0.0              0.0                UNK
# 20061025X01555                   NaN              NaN                IMC
# 20001218X45448                   0.0              0.0                IMC
# 20041105X01764                   NaN              0.0                VMC
# ...                              ...              ...                ...
# 20221227106491                   0.0              0.0            Unknown
# 20221227106494                   0.0              0.0            Unknown
# 20221227106497                   0.0              1.0                VMC
# 20221227106498                   0.0              0.0            Unknown
# 20221230106513                   0.0              1.0            Unknown
#
#                 broad_phase_of_flight
# Event.Id
# 20001218X45444                 Cruise
# 20001218X45447                Unknown
# 20061025X01555                 Cruise
# 20001218X45448                 Cruise
# 20041105X01764               Approach
# ...                               ...
# 20221227106491                Unknown
# 20221227106494                Unknown
# 20221227106497                Unknown
# 20221227106498                Unknown
# 20221230106513                Unknown
#
# [88889 rows x 22 columns]

# %%
df1[df1["injury_severity"]== "Unavailable"]
# Out:
#                 event_date                           location  \
# Event.Id
# 20001214X36228  1985-04-02                 EAGLE MOUNTAIN, CA
# 20001213X32755  1987-12-16                   BOGOTA, COLOMBIA
# 20001213X25766  1988-05-21                  KINGSTON, Jamaica
# 20001213X27314  1988-11-03                   SVARSTAD, Norway
# 20001213X28159  1989-04-12  SANTO DOMINGO, Dominican Republic
# ...                    ...                                ...
# 20061122X01703  2006-11-18                  Leticia, Colombia
# 20070531X00673  2007-05-01       PETERBOROUGH, UNITED KINGDOM
# 20071108X01758  2007-05-25               ACARICUARA, COLOMBIA
# 20070905X01309  2007-08-15           WIENER NEUSTADT, AUSTRIA
# 20071001X01488  2007-09-16            BANBURY, UNITED KINGDOM
#
#                            country   latitude   longitude injury_severity  \
# Event.Id
# 20001214X36228       United States    Unknown     Unknown     Unavailable
# 20001213X32755            Colombia    Unknown     Unknown     Unavailable
# 20001213X25766             Jamaica    Unknown     Unknown     Unavailable
# 20001213X27314              Norway    Unknown     Unknown     Unavailable
# 20001213X28159  Dominican Republic    Unknown     Unknown     Unavailable
# ...                            ...        ...         ...             ...
# 20061122X01703            Colombia    Unknown     Unknown     Unavailable
# 20070531X00673      United Kingdom    Unknown     Unknown     Unavailable
# 20071108X01758            Colombia        0.7  -70.383333     Unavailable
# 20070905X01309             Austria  47.843333       16.26     Unavailable
# 20071001X01488      United Kingdom    Unknown     Unknown     Unavailable
#
#                aircraft_damage aircraft_category        make         model  \
# Event.Id
# 20001214X36228     Substantial           Unknown      Cessna           414
# 20001213X32755     Substantial           Unknown      Boeing      747-124F
# 20001213X25766       Destroyed           Unknown        Bell         222UT
# 20001213X27314       Destroyed           Unknown   Schweizer          269C
# 20001213X28159       Destroyed           Unknown       Beech           A80
# ...                        ...               ...         ...           ...
# 20061122X01703       Destroyed           Unknown      Boeing         B-727
# 20070531X00673     Substantial           Unknown  Eurocopter       AS355F2
# 20071108X01758     Substantial           Unknown     Douglas          DC-3
# 20070905X01309     Substantial           Unknown    Robinson  R-22 Beta II
# 20071001X01488     Substantial           Unknown       Piper     PA-32-301
#
#                 ...    engine_type  far_description schedule  \
# Event.Id        ...
# 20001214X36228  ...  Reciprocating          Unknown  Unknown
# 20001213X32755  ...        Unknown          Unknown     SCHD
# 20001213X25766  ...        Unknown          Unknown      UNK
# 20001213X27314  ...        Unknown          Unknown      UNK
# 20001213X28159  ...        Unknown          Unknown      UNK
# ...             ...            ...              ...      ...
# 20061122X01703  ...        Unknown          Unknown     NSCH
# 20070531X00673  ...        Unknown          Unknown     NSCH
# 20071108X01758  ...        Unknown          Unknown  Unknown
# 20070905X01309  ...        Unknown          Unknown  Unknown
# 20071001X01488  ...        Unknown          Unknown  Unknown
#
#                purpose_of_flight total_fatal_injuries total_serious_injuries  \
# Event.Id
# 20001214X36228           Unknown                  0.0                    0.0
# 20001213X32755           Unknown                  NaN                    NaN
# 20001213X25766       Positioning                  NaN                    NaN
# 20001213X27314     Instructional                  NaN                    NaN
# 20001213X28159          Business                  NaN                    NaN
# ...                          ...                  ...                    ...
# 20061122X01703           Unknown                  NaN                    NaN
# 20070531X00673           Unknown                  NaN                    NaN
# 20071108X01758          Business                  NaN                    NaN
# 20070905X01309     Instructional                  NaN                    NaN
# 20071001X01488           Unknown                  NaN                    NaN
#
#                 total_minor_injuries  total_uninjured  weather_condition  \
# Event.Id
# 20001214X36228                   0.0              0.0                VMC
# 20001213X32755                   NaN              NaN                UNK
# 20001213X25766                   NaN              NaN                VMC
# 20001213X27314                   NaN              NaN                VMC
# 20001213X28159                   NaN              NaN                VMC
# ...                              ...              ...                ...
# 20061122X01703                   NaN              NaN            Unknown
# 20070531X00673                   NaN              NaN            Unknown
# 20071108X01758                   NaN              NaN                VMC
# 20070905X01309                   NaN              NaN                VMC
# 20071001X01488                   NaN              NaN            Unknown
#
#                 broad_phase_of_flight
# Event.Id
# 20001214X36228                Landing
# 20001213X32755                Unknown
# 20001213X25766                Unknown
# 20001213X27314                Unknown
# 20001213X28159                Unknown
# ...                               ...
# 20061122X01703                Unknown
# 20070531X00673                Unknown
# 20071108X01758                Unknown
# 20070905X01309                Unknown
# 20071001X01488                Unknown
#
# [96 rows x 22 columns]

# %%
df1["injury_severity"] = df1["injury_severity"].str.replace("Unavailable", "Unknown")

# %%
#Checking whether there are still categoriacl columns with null values
df1.isna().sum()
# Out:
# event_date                    0
# location                      0
# country                       0
# latitude                      0
# longitude                     0
# injury_severity               0
# aircraft_damage               0
# aircraft_category             0
# make                          0
# model                         0
# amateur_built                 0
# number_of_engines          6084
# engine_type                   0
# far_description               0
# schedule                      0
# purpose_of_flight             0
# total_fatal_injuries      11401
# total_serious_injuries    12510
# total_minor_injuries      11933
# total_uninjured            5912
# weather_condition             0
# broad_phase_of_flight         0
# dtype: int64

# %%
#Checking the value counts of the categorical columns to see of there are repeated values that need to be replaced
for col in df1.select_dtypes(include="O"):
    val_cnt= df1[col].value_counts(dropna=False)
    print(f"{val_cnt}", '\n' )
# Out:
# event_date
# 1984-06-30    25
# 1982-05-16    25
# 2000-07-08    25
# 1983-08-05    24
# 1984-08-25    24
#               ..
# 2014-03-16     1
# 2014-03-15     1
# 2014-03-12     1
# 2014-03-10     1
# 2022-12-29     1
# Name: count, Length: 14782, dtype: int64
#
# location
# ANCHORAGE, AK       434
# MIAMI, FL           200
# ALBUQUERQUE, NM     196
# HOUSTON, TX         193
# CHICAGO, IL         184
#                    ...
# MALLARDS LDG, GA      1
# LODGEPOLE, MT         1
# VERNILLION, SD        1
# MCMECHEN, WV          1
# Brasnorte,            1
# Name: count, Length: 27758, dtype: int64
#
# country
# United States                       82248
# Brazil                                374
# Canada                                359
# Mexico                                358
# United Kingdom                        344
#                                     ...
# Saint Vincent and the Grenadines        1
# Cambodia                                1
# Malampa                                 1
# AY                                      1
# Turks and Caicos Islands                1
# Name: count, Length: 219, dtype: int64
#
# latitude
# Unknown      54507
# 332739N         19
# 335219N         18
# 32.815556       17
# 334118N         17
#              ...
# 345832N          1
# 31.991666        1
# 444947N          1
# 034358N          1
# 373829N          1
# Name: count, Length: 25593, dtype: int64
#
# longitude
# Unknown        54516
# 0112457W          24
# 1114342W          18
# 1151140W          17
# -104.673056       17
#                ...
# 0824538W           1
# 0782055W           1
# 0823627W           1
# 0116352W           1
# 0121410W           1
# Name: count, Length: 27157, dtype: int64
#
# injury_severity
# Non-Fatal     67357
# Fatal(1)       6167
# Fatal          5262
# Fatal(2)       3711
# Incident       2219
#               ...
# Fatal(270)        1
# Fatal(60)         1
# Fatal(43)         1
# Fatal(143)        1
# Fatal(153)        1
# Name: count, Length: 109, dtype: int64
#
# aircraft_damage
# Substantial    64148
# Destroyed      18623
# Unknown         3313
# Minor           2805
# Name: count, dtype: int64
#
# aircraft_category
# Unknown              56616
# Airplane             27617
# Helicopter            3440
# Glider                 508
# Balloon                231
# Gyrocraft              173
# Weight-Shift           161
# Powered Parachute       91
# Ultralight              30
# WSFT                     9
# Powered-Lift             5
# Blimp                    4
# UNK                      2
# Rocket                   1
# ULTR                     1
# Name: count, dtype: int64
#
# make
# Cessna             22227
# Piper              12029
# CESSNA              4922
# Beech               4330
# PIPER               2841
#                    ...
# Leonard Walters        1
# Maule Air Inc.         1
# Motley Vans            1
# Perlick                1
# ROYSE RALPH L          1
# Name: count, Length: 8237, dtype: int64
#
# model
# 152              2367
# 172              1756
# 172N             1164
# PA-28-140         932
# 150               829
#                  ...
# GC-1-A              1
# 737-3S3             1
# MBB-BK117-B2        1
# GLASSAIR GL25       1
# M-8 EAGLE           1
# Name: count, Length: 12318, dtype: int64
#
# amateur_built
# No         80312
# Yes         8475
# Unknown      102
# Name: count, dtype: int64
#
# engine_type
# Reciprocating      69530
# Unknown             9147
# Turbo Shaft         3609
# Turbo Prop          3391
# Turbo Fan           2481
# Turbo Jet            703
# Geared Turbofan       12
# Electric              10
# LR                     2
# NONE                   2
# Hybrid Rocket          1
# UNK                    1
# Name: count, dtype: int64
#
# far_description
# Unknown                           56888
# 091                               18221
# Part 91: General Aviation          6486
# NUSN                               1584
# NUSC                               1013
# 137                                1010
# 135                                 746
# 121                                 679
# Part 137: Agricultural              437
# UNK                                 371
# Part 135: Air Taxi & Commuter       298
# PUBU                                253
# 129                                 246
# Part 121: Air Carrier               165
# 133                                 107
# Part 129: Foreign                   100
# Non-U.S., Non-Commercial             97
# Non-U.S., Commercial                 93
# Part 133: Rotorcraft Ext. Load       32
# Public Use                           19
# 091K                                 14
# ARMF                                  8
# 125                                   5
# Part 125: 20+ Pax,6000+ lbs           5
# 107                                   4
# Public Aircraft                       2
# 103                                   2
# Part 91 Subpart K: Fractional         1
# Armed Forces                          1
# Part 91F: Special Flt Ops.            1
# 437                                   1
# Name: count, dtype: int64
#
# schedule
# Unknown    76307
# NSCH        4474
# UNK         4099
# SCHD        4009
# Name: count, dtype: int64
#
# purpose_of_flight
# Personal                     49448
# Unknown                      12994
# Instructional                10601
# Aerial Application            4712
# Business                      4018
# Positioning                   1646
# Other Work Use                1264
# Ferry                          812
# Aerial Observation             794
# Public Aircraft                720
# Executive/corporate            553
# Flight Test                    405
# Skydiving                      182
# External Load                  123
# Public Aircraft - Federal      105
# Banner Tow                     101
# Air Race show                   99
# Public Aircraft - Local         74
# Public Aircraft - State         64
# Air Race/show                   59
# Glider Tow                      53
# Firefighting                    40
# Air Drop                        11
# ASHO                             6
# PUBS                             4
# PUBL                             1
# Name: count, dtype: int64
#
# weather_condition
# VMC        77303
# IMC         5976
# Unknown     4492
# UNK          856
# Unk          262
# Name: count, dtype: int64
#
# broad_phase_of_flight
# Unknown        27713
# Landing        15428
# Takeoff        12493
# Cruise         10269
# Maneuvering     8144
# Approach        6546
# Climb           2034
# Taxi            1958
# Descent         1887
# Go-around       1353
# Standing         945
# Other            119
# Name: count, dtype: int64

# %%
#A function to help in standardization of the values in the columns
def clean_string_columns(df):
    """
    Strips whitespace, lowers then title-cases all string columns in a DataFrame.
    """
    for col in df.select_dtypes(include="O").columns:
        df[col] = df[col].astype(str).str.strip().str.lower().str.title()
    return df

clean_string_columns(df1)
# Out:
#                 event_date         location        country   latitude  \
# Event.Id
# 20001218X45444  1948-10-24  Moose Creek, Id  United States    Unknown
# 20001218X45447  1962-07-19   Bridgeport, Ca  United States    Unknown
# 20061025X01555  1974-08-30    Saltville, Va  United States  36.922223
# 20001218X45448  1977-06-19       Eureka, Ca  United States    Unknown
# 20041105X01764  1979-08-02       Canton, Oh  United States    Unknown
# ...                    ...              ...            ...        ...
# 20221227106491  2022-12-26    Annapolis, Md  United States    Unknown
# 20221227106494  2022-12-26      Hampton, Nh  United States    Unknown
# 20221227106497  2022-12-26       Payson, Az  United States    341525N
# 20221227106498  2022-12-26       Morgan, Ut  United States    Unknown
# 20221230106513  2022-12-29       Athens, Ga  United States    Unknown
#
#                  longitude injury_severity aircraft_damage aircraft_category  \
# Event.Id
# 20001218X45444     Unknown        Fatal(2)       Destroyed           Unknown
# 20001218X45447     Unknown        Fatal(4)       Destroyed           Unknown
# 20061025X01555  -81.878056        Fatal(3)       Destroyed           Unknown
# 20001218X45448     Unknown        Fatal(2)       Destroyed           Unknown
# 20041105X01764     Unknown        Fatal(1)       Destroyed           Unknown
# ...                    ...             ...             ...               ...
# 20221227106491     Unknown           Minor         Unknown           Unknown
# 20221227106494     Unknown         Unknown         Unknown           Unknown
# 20221227106497    1112021W       Non-Fatal     Substantial          Airplane
# 20221227106498     Unknown         Unknown         Unknown           Unknown
# 20221230106513     Unknown           Minor         Unknown           Unknown
#
#                                       make      model  ...    engine_type  \
# Event.Id                                               ...
# 20001218X45444                     Stinson      108-3  ...  Reciprocating
# 20001218X45447                       Piper   Pa24-180  ...  Reciprocating
# 20061025X01555                      Cessna       172M  ...  Reciprocating
# 20001218X45448                    Rockwell        112  ...  Reciprocating
# 20041105X01764                      Cessna        501  ...        Unknown
# ...                                    ...        ...  ...            ...
# 20221227106491                       Piper  Pa-28-151  ...        Unknown
# 20221227106494                    Bellanca       7Eca  ...        Unknown
# 20221227106497  American Champion Aircraft      8Gcbc  ...        Unknown
# 20221227106498                      Cessna       210N  ...        Unknown
# 20221230106513                       Piper  Pa-24-260  ...        Unknown
#
#                 far_description schedule purpose_of_flight  \
# Event.Id
# 20001218X45444          Unknown  Unknown          Personal
# 20001218X45447          Unknown  Unknown          Personal
# 20061025X01555          Unknown  Unknown          Personal
# 20001218X45448          Unknown  Unknown          Personal
# 20041105X01764          Unknown  Unknown          Personal
# ...                         ...      ...               ...
# 20221227106491              091  Unknown          Personal
# 20221227106494          Unknown  Unknown           Unknown
# 20221227106497              091  Unknown          Personal
# 20221227106498              091  Unknown          Personal
# 20221230106513              091  Unknown          Personal
#
#                total_fatal_injuries total_serious_injuries  \
# Event.Id
# 20001218X45444                  2.0                    0.0
# 20001218X45447                  4.0                    0.0
# 20061025X01555                  3.0                    NaN
# 20001218X45448                  2.0                    0.0
# 20041105X01764                  1.0                    2.0
# ...                             ...                    ...
# 20221227106491                  0.0                    1.0
# 20221227106494                  0.0                    0.0
# 20221227106497                  0.0                    0.0
# 20221227106498                  0.0                    0.0
# 20221230106513                  0.0                    1.0
#
#                 total_minor_injuries  total_uninjured  weather_condition  \
# Event.Id
# 20001218X45444                   0.0              0.0                Unk
# 20001218X45447                   0.0              0.0                Unk
# 20061025X01555                   NaN              NaN                Imc
# 20001218X45448                   0.0              0.0                Imc
# 20041105X01764                   NaN              0.0                Vmc
# ...                              ...              ...                ...
# 20221227106491                   0.0              0.0            Unknown
# 20221227106494                   0.0              0.0            Unknown
# 20221227106497                   0.0              1.0                Vmc
# 20221227106498                   0.0              0.0            Unknown
# 20221230106513                   0.0              1.0            Unknown
#
#                 broad_phase_of_flight
# Event.Id
# 20001218X45444                 Cruise
# 20001218X45447                Unknown
# 20061025X01555                 Cruise
# 20001218X45448                 Cruise
# 20041105X01764               Approach
# ...                               ...
# 20221227106491                Unknown
# 20221227106494                Unknown
# 20221227106497                Unknown
# 20221227106498                Unknown
# 20221230106513                Unknown
#
# [88889 rows x 22 columns]

# %%
#Checking the value counts of the categorical columns after standardization
for col in df1.select_dtypes(include="O"):
    val_cnt= df1[col].value_counts(dropna=False)
    print(f"{val_cnt}", '\n' )
# Out:
# event_date
# 1984-06-30    25
# 1982-05-16    25
# 2000-07-08    25
# 1983-08-05    24
# 1984-08-25    24
#               ..
# 2014-03-16     1
# 2014-03-15     1
# 2014-03-12     1
# 2014-03-10     1
# 2022-12-29     1
# Name: count, Length: 14782, dtype: int64
#
# location
# Anchorage, Ak       548
# Miami, Fl           275
# Houston, Tx         271
# Albuquerque, Nm     265
# Chicago, Il         256
#                    ...
# Medina, Mn            1
# Circle Pines, Mn      1
# Pine Island, Fl       1
# Churchtown, Oh        1
# Brasnorte,            1
# Name: count, Length: 21977, dtype: int64
#
# country
# United States                       82248
# Brazil                                374
# Canada                                359
# Mexico                                358
# United Kingdom                        344
#                                     ...
# St Lucia                                1
# Saint Vincent And The Grenadines        1
# Libya                                   1
# Palau                                   1
# Belarus                                 1
# Name: count, Length: 215, dtype: int64
#
# latitude
# Unknown      54507
# 332739N         19
# 335219N         18
# 334118N         17
# 32.815556       17
#              ...
# 342034N          1
# 433113N          1
# 343255N          1
# 345911N          1
# 373829N          1
# Name: count, Length: 25590, dtype: int64
#
# longitude
# Unknown        54516
# 0112457W          24
# 1114342W          18
# -104.673056       17
# 1151140W          17
#                ...
# 0101957W           1
# 1064131W           1
# 1114414W           1
# 0023500E           1
# 0121410W           1
# Name: count, Length: 27155, dtype: int64
#
# injury_severity
# Non-Fatal     67357
# Fatal(1)       6167
# Fatal          5262
# Fatal(2)       3711
# Incident       2219
#               ...
# Fatal(270)        1
# Fatal(60)         1
# Fatal(43)         1
# Fatal(143)        1
# Fatal(153)        1
# Name: count, Length: 109, dtype: int64
#
# aircraft_damage
# Substantial    64148
# Destroyed      18623
# Unknown         3313
# Minor           2805
# Name: count, dtype: int64
#
# aircraft_category
# Unknown              56616
# Airplane             27617
# Helicopter            3440
# Glider                 508
# Balloon                231
# Gyrocraft              173
# Weight-Shift           161
# Powered Parachute       91
# Ultralight              30
# Wsft                     9
# Powered-Lift             5
# Blimp                    4
# Unk                      2
# Rocket                   1
# Ultr                     1
# Name: count, dtype: int64
#
# make
# Cessna           27149
# Piper            14870
# Beech             5372
# Boeing            2745
# Bell              2722
#                  ...
# Cohen                1
# Kitchens             1
# Lutes                1
# Izatt                1
# Royse Ralph L        1
# Name: count, Length: 7587, dtype: int64
#
# model
# 152                 2367
# 172                 1756
# 172N                1164
# Pa-28-140            932
# 150                  829
#                     ...
# E75Nl                  1
# 747-273C               1
# Watcha-Mccall-It       1
# Md-520N                1
# M-8 Eagle              1
# Name: count, Length: 11646, dtype: int64
#
# amateur_built
# No         80312
# Yes         8475
# Unknown      102
# Name: count, dtype: int64
#
# engine_type
# Reciprocating      69530
# Unknown             9147
# Turbo Shaft         3609
# Turbo Prop          3391
# Turbo Fan           2481
# Turbo Jet            703
# Geared Turbofan       12
# Electric              10
# Lr                     2
# None                   2
# Hybrid Rocket          1
# Unk                    1
# Name: count, dtype: int64
#
# far_description
# Unknown                           56888
# 091                               18221
# Part 91: General Aviation          6486
# Nusn                               1584
# Nusc                               1013
# 137                                1010
# 135                                 746
# 121                                 679
# Part 137: Agricultural              437
# Unk                                 371
# Part 135: Air Taxi & Commuter       298
# Pubu                                253
# 129                                 246
# Part 121: Air Carrier               165
# 133                                 107
# Part 129: Foreign                   100
# Non-U.S., Non-Commercial             97
# Non-U.S., Commercial                 93
# Part 133: Rotorcraft Ext. Load       32
# Public Use                           19
# 091K                                 14
# Armf                                  8
# 125                                   5
# Part 125: 20+ Pax,6000+ Lbs           5
# 107                                   4
# Public Aircraft                       2
# 103                                   2
# Part 91 Subpart K: Fractional         1
# Armed Forces                          1
# Part 91F: Special Flt Ops.            1
# 437                                   1
# Name: count, dtype: int64
#
# schedule
# Unknown    76307
# Nsch        4474
# Unk         4099
# Schd        4009
# Name: count, dtype: int64
#
# purpose_of_flight
# Personal                     49448
# Unknown                      12994
# Instructional                10601
# Aerial Application            4712
# Business                      4018
# Positioning                   1646
# Other Work Use                1264
# Ferry                          812
# Aerial Observation             794
# Public Aircraft                720
# Executive/Corporate            553
# Flight Test                    405
# Skydiving                      182
# External Load                  123
# Public Aircraft - Federal      105
# Banner Tow                     101
# Air Race Show                   99
# Public Aircraft - Local         74
# Public Aircraft - State         64
# Air Race/Show                   59
# Glider Tow                      53
# Firefighting                    40
# Air Drop                        11
# Asho                             6
# Pubs                             4
# Publ                             1
# Name: count, dtype: int64
#
# weather_condition
# Vmc        77303
# Imc         5976
# Unknown     4492
# Unk         1118
# Name: count, dtype: int64
#
# broad_phase_of_flight
# Unknown        27713
# Landing        15428
# Takeoff        12493
# Cruise         10269
# Maneuvering     8144
# Approach        6546
# Climb           2034
# Taxi            1958
# Descent         1887
# Go-Around       1353
# Standing         945
# Other            119
# Name: count, dtype: int64

# %%
#Replacing the name of a value because the value is similar to the other one
df1["purpose_of_flight"]= df1["purpose_of_flight"].str.replace("Air Race/Show", "Air Race Show")
df1["purpose_of_flight"].value_counts()
# Out:
# purpose_of_flight
# Personal                     49448
# Unknown                      12994
# Instructional                10601
# Aerial Application            4712
# Business                      4018
# Positioning                   1646
# Other Work Use                1264
# Ferry                          812
# Aerial Observation             794
# Public Aircraft                720
# Executive/Corporate            553
# Flight Test                    405
# Skydiving                      182
# Air Race Show                  158
# External Load                  123
# Public Aircraft - Federal      105
# Banner Tow                     101
# Public Aircraft - Local         74
# Public Aircraft - State         64
# Glider Tow                      53
# Firefighting                    40
# Air Drop                        11
# Asho                             6
# Pubs                             4
# Publ                             1
# Name: count, dtype: int64

# %%
#Replacing the value "unk" with "Unknown" all through the dataset
df1.replace("Unk", "Unknown", inplace=True)
df1["schedule"].value_counts()
# Out:
# schedule
# Unknown    80406
# Nsch        4474
# Schd        4009
# Name: count, dtype: int64

# %%
#Checking for duplicates in the new dataset after cleaning
df1.duplicated().sum()
# Out:
# 31

# %%
#Dropping the duplicated rows
df1.drop_duplicates(inplace=True)
df1.duplicated().sum()
# Out:
# 0

# %%
#Checking the dataset after dropping duplicated rows to see if there is a difference in number of rows
df1.shape
# Out:
# (88858, 22)

# %%
#Checking for null values
df1.isna().sum()
# Out:
# event_date                    0
# location                      0
# country                       0
# latitude                      0
# longitude                     0
# injury_severity               0
# aircraft_damage               0
# aircraft_category             0
# make                          0
# model                         0
# amateur_built                 0
# number_of_engines          6081
# engine_type                   0
# far_description               0
# schedule                      0
# purpose_of_flight             0
# total_fatal_injuries      11398
# total_serious_injuries    12503
# total_minor_injuries      11926
# total_uninjured            5908
# weather_condition             0
# broad_phase_of_flight         0
# dtype: int64

# %%
#Checking for the skewness of the "number_of_engines" column
sns.kdeplot(df1["number_of_engines"])
plt.show()

# %%
#Filling the missing values in "number_of_engines" column with median
median_engines = df1["number_of_engines"].median()
df1["number_of_engines"].fillna(median_engines, inplace=True)
df1.isna().sum()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28560\947657908.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["number_of_engines"].fillna(median_engines, inplace=True)
# event_date                    0
# location                      0
# country                       0
# latitude                      0
# longitude                     0
# injury_severity               0
# aircraft_damage               0
# aircraft_category             0
# make                          0
# model                         0
# amateur_built                 0
# number_of_engines             0
# engine_type                   0
# far_description               0
# schedule                      0
# purpose_of_flight             0
# total_fatal_injuries      11398
# total_serious_injuries    12503
# total_minor_injuries      11926
# total_uninjured            5908
# weather_condition             0
# broad_phase_of_flight         0
# dtype: int64

# %%
#Checking for the skewness of the "total_fatal_injuries" column
sns.kdeplot(df1["total_fatal_injuries"])
plt.show()

# %%
#Filling the missing values in "total_fatal_injuries" column with median
median_fatal_injuries= df1["total_fatal_injuries"].median()
df1["total_fatal_injuries"].fillna(median_fatal_injuries, inplace=True)
df1.isna().sum()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28560\3944268219.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["total_fatal_injuries"].fillna(median_fatal_injuries, inplace=True)
# event_date                    0
# location                      0
# country                       0
# latitude                      0
# longitude                     0
# injury_severity               0
# aircraft_damage               0
# aircraft_category             0
# make                          0
# model                         0
# amateur_built                 0
# number_of_engines             0
# engine_type                   0
# far_description               0
# schedule                      0
# purpose_of_flight             0
# total_fatal_injuries          0
# total_serious_injuries    12503
# total_minor_injuries      11926
# total_uninjured            5908
# weather_condition             0
# broad_phase_of_flight         0
# dtype: int64

# %%
#Checking for the skewness of the "total_serious_injuries" column
sns.kdeplot(df1["total_serious_injuries"])
plt.show()

# %%
#Filling the missing values in "total_serious_injuries" column with median
median_serious_injuries= df1["total_serious_injuries"].median()
df1["total_serious_injuries"].fillna(median_serious_injuries, inplace=True)
df1.isna().sum()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28560\1221458615.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["total_serious_injuries"].fillna(median_serious_injuries, inplace=True)
# event_date                    0
# location                      0
# country                       0
# latitude                      0
# longitude                     0
# injury_severity               0
# aircraft_damage               0
# aircraft_category             0
# make                          0
# model                         0
# amateur_built                 0
# number_of_engines             0
# engine_type                   0
# far_description               0
# schedule                      0
# purpose_of_flight             0
# total_fatal_injuries          0
# total_serious_injuries        0
# total_minor_injuries      11926
# total_uninjured            5908
# weather_condition             0
# broad_phase_of_flight         0
# dtype: int64

# %%
#Checking for the skewness of the "total_minor_injuries" column
sns.kdeplot(df1["total_minor_injuries"])
plt.show()

# %%
#Filling the missing values in "total_minor_injuries" column with median
median_minor_injuries= df1["total_minor_injuries"].median()
df1["total_minor_injuries"].fillna(median_minor_injuries, inplace=True)
df1.isna().sum()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28560\2284886515.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["total_minor_injuries"].fillna(median_minor_injuries, inplace=True)
# event_date                   0
# location                     0
# country                      0
# latitude                     0
# longitude                    0
# injury_severity              0
# aircraft_damage              0
# aircraft_category            0
# make                         0
# model                        0
# amateur_built                0
# number_of_engines            0
# engine_type                  0
# far_description              0
# schedule                     0
# purpose_of_flight            0
# total_fatal_injuries         0
# total_serious_injuries       0
# total_minor_injuries         0
# total_uninjured           5908
# weather_condition            0
# broad_phase_of_flight        0
# dtype: int64

# %%
#Checking for the skewness of the "total_uninjured" column
sns.kdeplot(df1["total_uninjured"])
plt.show()

# %%
median_uninjured= df1["total_minor_injuries"].median()
median_uninjured
# Out:
# 0.0

# %%
#Filling the missing values in "total_uninjured" column with median
median_unijured= df1["total_uninjured"].median()
df1["total_uninjured"].fillna(median_unijured, inplace=True)
df1.isna().sum()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28560\1323823289.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["total_uninjured"].fillna(median_unijured, inplace=True)
# event_date                0
# location                  0
# country                   0
# latitude                  0
# longitude                 0
# injury_severity           0
# aircraft_damage           0
# aircraft_category         0
# make                      0
# model                     0
# amateur_built             0
# number_of_engines         0
# engine_type               0
# far_description           0
# schedule                  0
# purpose_of_flight         0
# total_fatal_injuries      0
# total_serious_injuries    0
# total_minor_injuries      0
# total_uninjured           0
# weather_condition         0
# broad_phase_of_flight     0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
#Grouping the values in the injury_severity column and adding a new column, to simplify our analysis
def simplify_injury_severity(severity):
    if pd.isna(severity):
        return "Unknown"
    severity = severity.strip().lower()
    
    if severity.startswith("fatal"):
        return "Fatal"
    elif severity == "non-fatal":
        return "Non-Fatal"
    elif severity == "serious":
        return "Serious"
    elif severity == "minor":
        return "Minor"
    elif severity == "none":
        return "None"
    elif severity == "unknown":
        return "Unknown"
    elif severity == "unavailable":
        return "Unavailable"
    else:
        return "Other"
df1["grouped_injury_severity"] = df1["injury_severity"].apply(simplify_injury_severity)
df1["grouped_injury_severity"].value_counts()
# Out:
# grouped_injury_severity
# Non-Fatal    67342
# Fatal        17816
# Other         2215
# Unknown       1095
# Minor          217
# Serious        173
# Name: count, dtype: int64

# %%
#Adding a new column that gives us the count of total people that were onboard
df1["total_onboard"] = (df1["total_fatal_injuries"] + df1["total_serious_injuries"] + df1["total_minor_injuries"] 
                          + df1["total_uninjured"])
df1.head(10)
# Out:
#                 event_date          location        country   latitude  \
# Event.Id
# 20001218X45444  1948-10-24   Moose Creek, Id  United States    Unknown
# 20001218X45447  1962-07-19    Bridgeport, Ca  United States    Unknown
# 20061025X01555  1974-08-30     Saltville, Va  United States  36.922223
# 20001218X45448  1977-06-19        Eureka, Ca  United States    Unknown
# 20041105X01764  1979-08-02        Canton, Oh  United States    Unknown
# 20170710X52551  1979-09-17        Boston, Ma  United States  42.445277
# 20001218X45446  1981-08-01        Cotton, Mn  United States    Unknown
# 20020909X01562  1982-01-01       Pullman, Wa  United States    Unknown
# 20020909X01561  1982-01-01  East Hanover, Nj  United States    Unknown
# 20020909X01560  1982-01-01  Jacksonville, Fl  United States    Unknown
#
#                  longitude injury_severity aircraft_damage aircraft_category  \
# Event.Id
# 20001218X45444     Unknown        Fatal(2)       Destroyed           Unknown
# 20001218X45447     Unknown        Fatal(4)       Destroyed           Unknown
# 20061025X01555  -81.878056        Fatal(3)       Destroyed           Unknown
# 20001218X45448     Unknown        Fatal(2)       Destroyed           Unknown
# 20041105X01764     Unknown        Fatal(1)       Destroyed           Unknown
# 20170710X52551  -70.758333       Non-Fatal     Substantial          Airplane
# 20001218X45446     Unknown        Fatal(4)       Destroyed           Unknown
# 20020909X01562     Unknown       Non-Fatal     Substantial          Airplane
# 20020909X01561     Unknown       Non-Fatal     Substantial          Airplane
# 20020909X01560     Unknown       Non-Fatal     Substantial           Unknown
#
#                              make         model  ... total_fatal_injuries  \
# Event.Id                                         ...
# 20001218X45444            Stinson         108-3  ...                  2.0
# 20001218X45447              Piper      Pa24-180  ...                  4.0
# 20061025X01555             Cessna          172M  ...                  3.0
# 20001218X45448           Rockwell           112  ...                  2.0
# 20041105X01764             Cessna           501  ...                  1.0
# 20170710X52551  Mcdonnell Douglas           Dc9  ...                  0.0
# 20001218X45446             Cessna           180  ...                  4.0
# 20020909X01562             Cessna           140  ...                  0.0
# 20020909X01561             Cessna          401B  ...                  0.0
# 20020909X01560     North American  Navion L-17B  ...                  0.0
#
#                 total_serious_injuries total_minor_injuries total_uninjured  \
# Event.Id
# 20001218X45444                     0.0                  0.0             0.0
# 20001218X45447                     0.0                  0.0             0.0
# 20061025X01555                     0.0                  0.0             1.0
# 20001218X45448                     0.0                  0.0             0.0
# 20041105X01764                     2.0                  0.0             0.0
# 20170710X52551                     0.0                  1.0            44.0
# 20001218X45446                     0.0                  0.0             0.0
# 20020909X01562                     0.0                  0.0             2.0
# 20020909X01561                     0.0                  0.0             2.0
# 20020909X01560                     0.0                  3.0             0.0
#
#                weather_condition broad_phase_of_flight  \
# Event.Id
# 20001218X45444           Unknown                Cruise
# 20001218X45447           Unknown               Unknown
# 20061025X01555               Imc                Cruise
# 20001218X45448               Imc                Cruise
# 20041105X01764               Vmc              Approach
# 20170710X52551               Vmc                 Climb
# 20001218X45446               Imc               Unknown
# 20020909X01562               Vmc               Takeoff
# 20020909X01561               Imc               Landing
# 20020909X01560               Imc                Cruise
#
#                 grouped_injury_severity  total_passengers  injury_rate  \
# Event.Id
# 20001218X45444                    Fatal               2.0         1.00
# 20001218X45447                    Fatal               4.0         1.00
# 20061025X01555                    Fatal               4.0         0.75
# 20001218X45448                    Fatal               2.0         1.00
# 20041105X01764                    Fatal               3.0         1.00
# 20170710X52551                Non-Fatal              45.0         0.02
# 20001218X45446                    Fatal               4.0         1.00
# 20020909X01562                Non-Fatal               2.0         0.00
# 20020909X01561                Non-Fatal               2.0         0.00
# 20020909X01560                Non-Fatal               3.0         1.00
#
#                 total_onboard
# Event.Id
# 20001218X45444            2.0
# 20001218X45447            4.0
# 20061025X01555            4.0
# 20001218X45448            2.0
# 20041105X01764            3.0
# 20170710X52551           45.0
# 20001218X45446            4.0
# 20020909X01562            2.0
# 20020909X01561            2.0
# 20020909X01560            3.0
#
# [10 rows x 26 columns]

# %%
df1[df1["total_onboard"] == 0]
# Out:
#                 event_date              location        country latitude  \
# Event.Id
# 20001214X36228  1985-04-02    Eagle Mountain, Ca  United States  Unknown
# 20001213X35066  1986-10-05           Seattle, Wa  United States  Unknown
# 20001206X02391  1994-10-13               Unknown    Switzerland  Unknown
# 20001208X06824  1996-09-25  Holland, Netherlands    Netherlands  Unknown
# 20010108X00057  1997-03-03           Atlanta, Ga  United States  Unknown
# ...                    ...                   ...            ...      ...
# 20221220106480  2022-12-13           Liberal, Ks  United States  Unknown
# 20221215106462  2022-12-15         Patterson, La  United States  Unknown
# 20221219106472  2022-12-18           Kahului, Hi  United States  Unknown
# 20221227106494  2022-12-26           Hampton, Nh  United States  Unknown
# 20221227106498  2022-12-26            Morgan, Ut  United States  Unknown
#
#                longitude injury_severity aircraft_damage aircraft_category  \
# Event.Id
# 20001214X36228   Unknown         Unknown     Substantial           Unknown
# 20001213X35066   Unknown        Incident           Minor           Unknown
# 20001206X02391   Unknown         Unknown     Substantial           Unknown
# 20001208X06824   Unknown         Unknown       Destroyed           Unknown
# 20010108X00057   Unknown        Incident           Minor           Unknown
# ...                  ...             ...             ...               ...
# 20221220106480   Unknown       Non-Fatal         Unknown           Unknown
# 20221215106462   Unknown         Unknown         Unknown           Unknown
# 20221219106472   Unknown         Unknown         Unknown           Unknown
# 20221227106494   Unknown         Unknown         Unknown           Unknown
# 20221227106498   Unknown         Unknown         Unknown           Unknown
#
#                              make       model  ... total_fatal_injuries  \
# Event.Id                                       ...
# 20001214X36228             Cessna         414  ...                  0.0
# 20001213X35066  Mcdonnell Douglas    Dc-10-10  ...                  0.0
# 20001206X02391              Piper  Pa28Rt-201  ...                  0.0
# 20001208X06824            Douglas        Dc-3  ...                  0.0
# 20010108X00057             Boeing        727F  ...                  0.0
# ...                           ...         ...  ...                  ...
# 20221220106480             Cessna         441  ...                  0.0
# 20221215106462               Bell      206-L4  ...                  0.0
# 20221219106472             Airbus    A330-243  ...                  0.0
# 20221227106494           Bellanca        7Eca  ...                  0.0
# 20221227106498             Cessna        210N  ...                  0.0
#
#                 total_serious_injuries total_minor_injuries total_uninjured  \
# Event.Id
# 20001214X36228                     0.0                  0.0             0.0
# 20001213X35066                     0.0                  0.0             0.0
# 20001206X02391                     0.0                  0.0             0.0
# 20001208X06824                     0.0                  0.0             0.0
# 20010108X00057                     0.0                  0.0             0.0
# ...                                ...                  ...             ...
# 20221220106480                     0.0                  0.0             0.0
# 20221215106462                     0.0                  0.0             0.0
# 20221219106472                     0.0                  0.0             0.0
# 20221227106494                     0.0                  0.0             0.0
# 20221227106498                     0.0                  0.0             0.0
#
#                weather_condition broad_phase_of_flight  \
# Event.Id
# 20001214X36228               Vmc               Landing
# 20001213X35066           Unknown              Standing
# 20001206X02391           Unknown               Unknown
# 20001208X06824           Unknown               Unknown
# 20010108X00057           Unknown              Standing
# ...                          ...                   ...
# 20221220106480           Unknown               Unknown
# 20221215106462           Unknown               Unknown
# 20221219106472           Unknown               Unknown
# 20221227106494           Unknown               Unknown
# 20221227106498           Unknown               Unknown
#
#                 grouped_injury_severity  total_passengers  injury_rate  \
# Event.Id
# 20001214X36228                  Unknown               0.0          NaN
# 20001213X35066                    Other               0.0          NaN
# 20001206X02391                  Unknown               0.0          NaN
# 20001208X06824                  Unknown               0.0          NaN
# 20010108X00057                    Other               0.0          NaN
# ...                                 ...               ...          ...
# 20221220106480                Non-Fatal               0.0          NaN
# 20221215106462                  Unknown               0.0          NaN
# 20221219106472                  Unknown               0.0          NaN
# 20221227106494                  Unknown               0.0          NaN
# 20221227106498                  Unknown               0.0          NaN
#
#                 total_onboard
# Event.Id
# 20001214X36228            0.0
# 20001213X35066            0.0
# 20001206X02391            0.0
# 20001208X06824            0.0
# 20010108X00057            0.0
# ...                       ...
# 20221220106480            0.0
# 20221215106462            0.0
# 20221219106472            0.0
# 20221227106494            0.0
# 20221227106498            0.0
#
# [1085 rows x 26 columns]

# %%
df1["injury_rate"] = ((df1["total_fatal_injuries"] + df1["total_serious_injuries"] + df1["total_minor_injuries"]) 
                     / df1["total_onboard"]).round(2)
df1.head(10)
# Out:
#                 event_date          location        country   latitude  \
# Event.Id
# 20001218X45444  1948-10-24   Moose Creek, Id  United States    Unknown
# 20001218X45447  1962-07-19    Bridgeport, Ca  United States    Unknown
# 20061025X01555  1974-08-30     Saltville, Va  United States  36.922223
# 20001218X45448  1977-06-19        Eureka, Ca  United States    Unknown
# 20041105X01764  1979-08-02        Canton, Oh  United States    Unknown
# 20170710X52551  1979-09-17        Boston, Ma  United States  42.445277
# 20001218X45446  1981-08-01        Cotton, Mn  United States    Unknown
# 20020909X01562  1982-01-01       Pullman, Wa  United States    Unknown
# 20020909X01561  1982-01-01  East Hanover, Nj  United States    Unknown
# 20020909X01560  1982-01-01  Jacksonville, Fl  United States    Unknown
#
#                  longitude injury_severity aircraft_damage aircraft_category  \
# Event.Id
# 20001218X45444     Unknown        Fatal(2)       Destroyed           Unknown
# 20001218X45447     Unknown        Fatal(4)       Destroyed           Unknown
# 20061025X01555  -81.878056        Fatal(3)       Destroyed           Unknown
# 20001218X45448     Unknown        Fatal(2)       Destroyed           Unknown
# 20041105X01764     Unknown        Fatal(1)       Destroyed           Unknown
# 20170710X52551  -70.758333       Non-Fatal     Substantial          Airplane
# 20001218X45446     Unknown        Fatal(4)       Destroyed           Unknown
# 20020909X01562     Unknown       Non-Fatal     Substantial          Airplane
# 20020909X01561     Unknown       Non-Fatal     Substantial          Airplane
# 20020909X01560     Unknown       Non-Fatal     Substantial           Unknown
#
#                              make         model  ... purpose_of_flight  \
# Event.Id                                         ...
# 20001218X45444            Stinson         108-3  ...          Personal
# 20001218X45447              Piper      Pa24-180  ...          Personal
# 20061025X01555             Cessna          172M  ...          Personal
# 20001218X45448           Rockwell           112  ...          Personal
# 20041105X01764             Cessna           501  ...          Personal
# 20170710X52551  Mcdonnell Douglas           Dc9  ...           Unknown
# 20001218X45446             Cessna           180  ...          Personal
# 20020909X01562             Cessna           140  ...          Personal
# 20020909X01561             Cessna          401B  ...          Business
# 20020909X01560     North American  Navion L-17B  ...          Personal
#
#                 total_fatal_injuries total_serious_injuries  \
# Event.Id
# 20001218X45444                   2.0                    0.0
# 20001218X45447                   4.0                    0.0
# 20061025X01555                   3.0                    0.0
# 20001218X45448                   2.0                    0.0
# 20041105X01764                   1.0                    2.0
# 20170710X52551                   0.0                    0.0
# 20001218X45446                   4.0                    0.0
# 20020909X01562                   0.0                    0.0
# 20020909X01561                   0.0                    0.0
# 20020909X01560                   0.0                    0.0
#
#                total_minor_injuries total_uninjured weather_condition  \
# Event.Id
# 20001218X45444                  0.0             0.0           Unknown
# 20001218X45447                  0.0             0.0           Unknown
# 20061025X01555                  0.0             1.0               Imc
# 20001218X45448                  0.0             0.0               Imc
# 20041105X01764                  0.0             0.0               Vmc
# 20170710X52551                  1.0            44.0               Vmc
# 20001218X45446                  0.0             0.0               Imc
# 20020909X01562                  0.0             2.0               Vmc
# 20020909X01561                  0.0             2.0               Imc
# 20020909X01560                  3.0             0.0               Imc
#
#                 broad_phase_of_flight  grouped_injury_severity  \
# Event.Id
# 20001218X45444                 Cruise                    Fatal
# 20001218X45447                Unknown                    Fatal
# 20061025X01555                 Cruise                    Fatal
# 20001218X45448                 Cruise                    Fatal
# 20041105X01764               Approach                    Fatal
# 20170710X52551                  Climb                Non-Fatal
# 20001218X45446                Unknown                    Fatal
# 20020909X01562                Takeoff                Non-Fatal
# 20020909X01561                Landing                Non-Fatal
# 20020909X01560                 Cruise                Non-Fatal
#
#                 total_passengers  injury_rate
# Event.Id
# 20001218X45444               2.0         1.00
# 20001218X45447               4.0         1.00
# 20061025X01555               4.0         0.75
# 20001218X45448               2.0         1.00
# 20041105X01764               3.0         1.00
# 20170710X52551              45.0         0.02
# 20001218X45446               4.0         1.00
# 20020909X01562               2.0         0.00
# 20020909X01561               2.0         0.00
# 20020909X01560               3.0         1.00
#
# [10 rows x 25 columns]

# %%
df1.isna().sum()
# Out:
# event_date                    0
# location                      0
# country                       0
# latitude                      0
# longitude                     0
# injury_severity               0
# aircraft_damage               0
# aircraft_category             0
# make                          0
# model                         0
# amateur_built                 0
# number_of_engines             0
# engine_type                   0
# far_description               0
# schedule                      0
# purpose_of_flight             0
# total_fatal_injuries          0
# total_serious_injuries        0
# total_minor_injuries          0
# total_uninjured               0
# weather_condition             0
# broad_phase_of_flight         0
# grouped_injury_severity       0
# total_passengers              0
# injury_rate                1085
# dtype: int64
